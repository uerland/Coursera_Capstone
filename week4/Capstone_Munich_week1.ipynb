# %% [markdown]
# # Battle of Neighborhoods (Week 1)

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Munich is the most important center of commerce and industry in Germany and among top in Europe. Not only because of that, it is expected that the population of Munich will increase by more than 10% within the next 20 years [(source)](https://www.br.de/nachrichten/bayern/bevoelkerungsprognose-region-muenchen-wird-voller-und-juenger,RKadnKj).
#
# ![Munich](https://upload.wikimedia.org/wikipedia/commons/c/cd/Frauenkirche_in_M%C3%BCnchen.jpg "City of Munich")
# (By Reinald Kirchner - originally posted to Flickr as Frauenkirche in München, [CC BY-SA 2.0](https://commons.wikimedia.org/w/index.php?curid=7882323))
#
#
# This project will look into the prospect of launching an Italian restaurant in the major business discricts of Munich. On one hand, the target audience are indeed business people seeking to open a restaurant. On the other hand, results of the analysis also provide hints on where to find interesting restaurants in Munich.
#
#
# Please find the outline of the project below:
# 1. Apply web scrapping to get the names and basic information about Munich's districts
# 2. Select the districts to focus on
# 3. Use Foresquare data to obtain information about restaurants
#     * Perform basic visualization and statistical anlysis on the data
#     * Apply k-means clustering on the data
# 4. Visualization using Chloropleth map

# %% [markdown]
# ## 2. Data

# %% [markdown]
# ### Install and import necessary packages

# %%
# !conda install --insecure -c conda-forge folium=0.5.0 --yes
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import pandas as pd
import numpy as np
import requests
import geopy
from bs4 import BeautifulSoup

# %% [markdown]
# ### Scrapping wikipedia for names and information on districts

# %%
# source page
wiki_page = requests.get("https://de.wikipedia.org/w/index.php?title=Stadtbezirke_M%C3%BCnchens").text
soup = BeautifulSoup(wiki_page,'lxml')

# grab desired table type
table = soup.find('table',{'class':'wikitable sortable'})

# %% [markdown]
# Read data into dataframe

# %%
df = pd.read_html(str(table))

df = df[0]
df
# Out:
#      Nr.                                        Stadtbezirk  Fläche(km²)  \
# 0    1.0                                     Altstadt-Lehel          315
# 1    2.0                       Ludwigsvorstadt-Isarvorstadt          440
# 2    3.0                                        Maxvorstadt          430
# 3    4.0                                     Schwabing-West          436
# 4    5.0                                      Au-Haidhausen          422
# 5    6.0                                           Sendling          394
# 6    7.0                                  Sendling-Westpark          781
# 7    8.0                                   Schwanthalerhöhe          207
# 8    9.0                              Neuhausen-Nymphenburg         1291
# 9   10.0                                            Moosach         1109
# 10  11.0                              Milbertshofen-Am Hart         1342
# 11  12.0                                 Schwabing-Freimann         2567
# 12  13.0                                        Bogenhausen         2371
# 13  14.0                                       Berg am Laim          631
# 14  15.0                                     Trudering-Riem         2245
# 15  16.0                                 Ramersdorf-Perlach         1990
# 16  17.0                            Obergiesing-Fasangarten          572
# 17  18.0                            Untergiesing-Harlaching          806
# 18  19.0  Thalkirchen-Obersendling-Forstenried-Fürstenri...         1776
# 19  20.0                                             Hadern          922
# 20  21.0                                 Pasing-Obermenzing         1650
# 21  22.0                         Aubing-Lochhausen-Langwied         3406
# 22  23.0                                Allach-Untermenzing         1545
# 23  24.0                             Feldmoching-Hasenbergl         2894
# 24  25.0                                               Laim          529
# 25   NaN                           Landeshauptstadt München        31071
#
#     Einwohner  Dichte(Einw./km²)  Ausländer(%)
# 0      21.100              6.708           261
# 1      51.644             11.734           284
# 2      51.402             11.960           254
# 3      68.527             15.706           227
# 4      61.356             14.541           235
# 5      40.983             10.405           269
# 6      59.643              7.632           289
# 7      29.743             14.367           335
# 8      98.814              7.651           243
# 9      54.223              4.888           315
# 10     75.094              5.597           408
# 11     77.936              3.036           293
# 12     87.950              3.709           244
# 13     46.098              7.300           319
# 14     73.206              3.261           233
# 15    116.327              5.847           339
# 16     54.256              9.485           311
# 17     53.184              6.601           241
# 18     96.714              5.445           274
# 19     49.898              5.410           273
# 20     74.625              4.523           229
# 21     47.813              1.404           284
# 22     33.355              2.159           242
# 23     61.774              2.135           324
# 24     56.546             10.698           285
# 25  1.542.211              4.963           281

# %% [markdown]
# Drop the summation (last) row last two columns

# %%
df.drop(df.tail(1).index,inplace=True)
df.drop(['Dichte(Einw./km²)', 'Ausländer(%)'], axis=1,inplace=True)
df
# Out:
#      Nr.                                        Stadtbezirk  Fläche(km²)  \
# 0    1.0                                     Altstadt-Lehel          315
# 1    2.0                       Ludwigsvorstadt-Isarvorstadt          440
# 2    3.0                                        Maxvorstadt          430
# 3    4.0                                     Schwabing-West          436
# 4    5.0                                      Au-Haidhausen          422
# 5    6.0                                           Sendling          394
# 6    7.0                                  Sendling-Westpark          781
# 7    8.0                                   Schwanthalerhöhe          207
# 8    9.0                              Neuhausen-Nymphenburg         1291
# 9   10.0                                            Moosach         1109
# 10  11.0                              Milbertshofen-Am Hart         1342
# 11  12.0                                 Schwabing-Freimann         2567
# 12  13.0                                        Bogenhausen         2371
# 13  14.0                                       Berg am Laim          631
# 14  15.0                                     Trudering-Riem         2245
# 15  16.0                                 Ramersdorf-Perlach         1990
# 16  17.0                            Obergiesing-Fasangarten          572
# 17  18.0                            Untergiesing-Harlaching          806
# 18  19.0  Thalkirchen-Obersendling-Forstenried-Fürstenri...         1776
# 19  20.0                                             Hadern          922
# 20  21.0                                 Pasing-Obermenzing         1650
# 21  22.0                         Aubing-Lochhausen-Langwied         3406
# 22  23.0                                Allach-Untermenzing         1545
# 23  24.0                             Feldmoching-Hasenbergl         2894
# 24  25.0                                               Laim          529
#
#    Einwohner
# 0     21.100
# 1     51.644
# 2     51.402
# 3     68.527
# 4     61.356
# 5     40.983
# 6     59.643
# 7     29.743
# 8     98.814
# 9     54.223
# 10    75.094
# 11    77.936
# 12    87.950
# 13    46.098
# 14    73.206
# 15   116.327
# 16    54.256
# 17    53.184
# 18    96.714
# 19    49.898
# 20    74.625
# 21    47.813
# 22    33.355
# 23    61.774
# 24    56.546

# %% [markdown]
# Recast district number as integer and translate column names

# %%
df["Nr."]= df["Nr."].astype(int)

# translation
df.columns = ['No.', 'district', 'area', 'population']
df
# Out:
#     No.                                           district  area population
# 0     1                                     Altstadt-Lehel   315     21.100
# 1     2                       Ludwigsvorstadt-Isarvorstadt   440     51.644
# 2     3                                        Maxvorstadt   430     51.402
# 3     4                                     Schwabing-West   436     68.527
# 4     5                                      Au-Haidhausen   422     61.356
# 5     6                                           Sendling   394     40.983
# 6     7                                  Sendling-Westpark   781     59.643
# 7     8                                   Schwanthalerhöhe   207     29.743
# 8     9                              Neuhausen-Nymphenburg  1291     98.814
# 9    10                                            Moosach  1109     54.223
# 10   11                              Milbertshofen-Am Hart  1342     75.094
# 11   12                                 Schwabing-Freimann  2567     77.936
# 12   13                                        Bogenhausen  2371     87.950
# 13   14                                       Berg am Laim   631     46.098
# 14   15                                     Trudering-Riem  2245     73.206
# 15   16                                 Ramersdorf-Perlach  1990    116.327
# 16   17                            Obergiesing-Fasangarten   572     54.256
# 17   18                            Untergiesing-Harlaching   806     53.184
# 18   19  Thalkirchen-Obersendling-Forstenried-Fürstenri...  1776     96.714
# 19   20                                             Hadern   922     49.898
# 20   21                                 Pasing-Obermenzing  1650     74.625
# 21   22                         Aubing-Lochhausen-Langwied  3406     47.813
# 22   23                                Allach-Untermenzing  1545     33.355
# 23   24                             Feldmoching-Hasenbergl  2894     61.774
# 24   25                                               Laim   529     56.546

# %% [markdown]
# ### Get coordinates

# %% [markdown]
# Simply passing the name of the district to the geocoder may lead to unfavorable results. For a distinct search result, the query name needs to be adapted to e.g. 'Stadtbezirk 01 Altstadt-Lehel'. 'Stadtbezirk' being German for district, '01' being the district number, and 'Alstadt-Lehel' the corresponding district name.

# %%
df['Search term'] = 'Stadtbezirk '+df['No.'].astype(str).apply(lambda x: x.zfill(2))+' '+df['district'].astype(str)
df
# Out:
#     No.                                           district  area population  \
# 0     1                                     Altstadt-Lehel   315     21.100
# 1     2                       Ludwigsvorstadt-Isarvorstadt   440     51.644
# 2     3                                        Maxvorstadt   430     51.402
# 3     4                                     Schwabing-West   436     68.527
# 4     5                                      Au-Haidhausen   422     61.356
# 5     6                                           Sendling   394     40.983
# 6     7                                  Sendling-Westpark   781     59.643
# 7     8                                   Schwanthalerhöhe   207     29.743
# 8     9                              Neuhausen-Nymphenburg  1291     98.814
# 9    10                                            Moosach  1109     54.223
# 10   11                              Milbertshofen-Am Hart  1342     75.094
# 11   12                                 Schwabing-Freimann  2567     77.936
# 12   13                                        Bogenhausen  2371     87.950
# 13   14                                       Berg am Laim   631     46.098
# 14   15                                     Trudering-Riem  2245     73.206
# 15   16                                 Ramersdorf-Perlach  1990    116.327
# 16   17                            Obergiesing-Fasangarten   572     54.256
# 17   18                            Untergiesing-Harlaching   806     53.184
# 18   19  Thalkirchen-Obersendling-Forstenried-Fürstenri...  1776     96.714
# 19   20                                             Hadern   922     49.898
# 20   21                                 Pasing-Obermenzing  1650     74.625
# 21   22                         Aubing-Lochhausen-Langwied  3406     47.813
# 22   23                                Allach-Untermenzing  1545     33.355
# 23   24                             Feldmoching-Hasenbergl  2894     61.774
# 24   25                                               Laim   529     56.546
#
#                                           Search term
# 0                       Stadtbezirk 01 Altstadt-Lehel
# 1         Stadtbezirk 02 Ludwigsvorstadt-Isarvorstadt
# 2                          Stadtbezirk 03 Maxvorstadt
# 3                       Stadtbezirk 04 Schwabing-West
# 4                        Stadtbezirk 05 Au-Haidhausen
# 5                             Stadtbezirk 06 Sendling
# 6                    Stadtbezirk 07 Sendling-Westpark
# 7                     Stadtbezirk 08 Schwanthalerhöhe
# 8                Stadtbezirk 09 Neuhausen-Nymphenburg
# 9                              Stadtbezirk 10 Moosach
# 10               Stadtbezirk 11 Milbertshofen-Am Hart
# 11                  Stadtbezirk 12 Schwabing-Freimann
# 12                         Stadtbezirk 13 Bogenhausen
# 13                        Stadtbezirk 14 Berg am Laim
# 14                      Stadtbezirk 15 Trudering-Riem
# 15                  Stadtbezirk 16 Ramersdorf-Perlach
# 16             Stadtbezirk 17 Obergiesing-Fasangarten
# 17             Stadtbezirk 18 Untergiesing-Harlaching
# 18  Stadtbezirk 19 Thalkirchen-Obersendling-Forste...
# 19                              Stadtbezirk 20 Hadern
# 20                  Stadtbezirk 21 Pasing-Obermenzing
# 21          Stadtbezirk 22 Aubing-Lochhausen-Langwied
# 22                 Stadtbezirk 23 Allach-Untermenzing
# 23              Stadtbezirk 24 Feldmoching-Hasenbergl
# 24                                Stadtbezirk 25 Laim

# %% [markdown]
# Processing of geocoder on the whole dataframe may lead to time-out errors. Instead, manually looping over each row of the dataframe turns out to be a robust approach

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Munich_explorer")

#df['district_coord'] = df['Search term'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
#df

import time
coords = []
for i,r in df.iterrows():
    location = geolocator.geocode(r['Search term'])
    coords.append(location[1])
    print(location[0], location[1])
    time.sleep(2) # pause between search request
#coords
# Out:
# Stadtbezirk 01 Altstadt-Lehel, München, Bayern, Deutschland (48.143648049999996, 11.589578888860586)
# Stadtbezirk 02 Ludwigsvorstadt-Isarvorstadt, München, Bayern, Deutschland (48.130722250000005, 11.566525978684702)
# Stadtbezirk 03 Maxvorstadt, München, Bayern, Deutschland (48.1465704, 11.5714445)
# Stadtbezirk 04 Schwabing-West, München, Bayern, Deutschland (48.166354049999995, 11.566190844059609)
# Stadtbezirk 05 Au-Haidhausen, München, Bayern, Deutschland (48.130273849999995, 11.59833361534854)
# Stadtbezirk 06 Sendling, München, Bayern, 81371, Deutschland (48.1159214, 11.54838668124458)
# Stadtbezirk 07 Sendling-Westpark, München, Bayern, Deutschland (48.11803085, 11.519332770284128)
# Stadtbezirk 08 Schwanthalerhöhe, München, Bayern, 80339, Deutschland (48.13458915, 11.538012925336673)
# Stadtbezirk 09 Neuhausen-Nymphenburg, München, Bayern, Deutschland (48.1566258, 11.518015570976043)
# Stadtbezirk 10 Moosach, München, Bayern, Deutschland (48.1854255, 11.515593609710727)
# Stadtbezirk 11 Milbertshofen-Am Hart, München, Bayern, Deutschland (48.1975317, 11.577299846428875)
# Stadtbezirk 12 Schwabing-Freimann, München, Bayern, Deutschland (48.1892784, 11.60858258301819)
# Stadtbezirk 13 Bogenhausen, München, Bayern, Deutschland (48.1584875, 11.63668238460353)
# Stadtbezirk 14 Berg am Laim, München, Bayern, Deutschland (48.1256128, 11.629556660669579)
# Stadtbezirk 15 Trudering-Riem, München, Bayern, Deutschland (48.1266781, 11.685295742439251)
# Stadtbezirk 16 Ramersdorf - Perlach, München, Bayern, Deutschland (48.100894249999996, 11.633370907753356)
# Stadtbezirk 17 Obergiesing-Fasangarten, München, Bayern, Deutschland (48.10393445, 11.590683288923096)
# Stadtbezirk 18 Untergiesing-Harlaching, München, Bayern, Deutschland (48.0953796, 11.569129439027801)
# Stadtbezirk 19 Thalkirchen-Obersendling-Forstenried-Fürstenried-Solln, München, Bayern, Deutschland (48.0842133, 11.508050993496012)
# Stadtbezirk 20 Hadern, München, Bayern, Deutschland (48.113192850000004, 11.482850155133889)
# Stadtbezirk 21 Pasing-Obermenzing, München, Bayern, Deutschland (48.15236275, 11.468434085049713)
# Stadtbezirk 22 Aubing-Lochhausen-Langwied, München, Bayern, Deutschland (48.16505875, 11.40022147296721)
# Stadtbezirk 23 Allach-Untermenzing, München, Bayern, Deutschland (48.19515735, 11.462973336774297)
# Stadtbezirk 24 Feldmoching-Hasenbergl, München, Bayern, Deutschland (48.21846185, 11.520409083159603)
# Stadtbezirk 25 Laim, München, Bayern, Deutschland (48.1363098, 11.505332809377975)

# %% [markdown]
# Create the final data frame by adding the coordinates

# %%
df['district_coord'] = coords
df[['Latitude', 'Longitude']] = df['district_coord'].apply(pd.Series)
df.drop(['district_coord'], axis=1, inplace=True)
df
# Out:
#     No.                                           district  area population  \
# 0     1                                     Altstadt-Lehel   315     21.100
# 1     2                       Ludwigsvorstadt-Isarvorstadt   440     51.644
# 2     3                                        Maxvorstadt   430     51.402
# 3     4                                     Schwabing-West   436     68.527
# 4     5                                      Au-Haidhausen   422     61.356
# 5     6                                           Sendling   394     40.983
# 6     7                                  Sendling-Westpark   781     59.643
# 7     8                                   Schwanthalerhöhe   207     29.743
# 8     9                              Neuhausen-Nymphenburg  1291     98.814
# 9    10                                            Moosach  1109     54.223
# 10   11                              Milbertshofen-Am Hart  1342     75.094
# 11   12                                 Schwabing-Freimann  2567     77.936
# 12   13                                        Bogenhausen  2371     87.950
# 13   14                                       Berg am Laim   631     46.098
# 14   15                                     Trudering-Riem  2245     73.206
# 15   16                                 Ramersdorf-Perlach  1990    116.327
# 16   17                            Obergiesing-Fasangarten   572     54.256
# 17   18                            Untergiesing-Harlaching   806     53.184
# 18   19  Thalkirchen-Obersendling-Forstenried-Fürstenri...  1776     96.714
# 19   20                                             Hadern   922     49.898
# 20   21                                 Pasing-Obermenzing  1650     74.625
# 21   22                         Aubing-Lochhausen-Langwied  3406     47.813
# 22   23                                Allach-Untermenzing  1545     33.355
# 23   24                             Feldmoching-Hasenbergl  2894     61.774
# 24   25                                               Laim   529     56.546
#
#                                           Search term   Latitude  Longitude
# 0                       Stadtbezirk 01 Altstadt-Lehel  48.143648  11.589579
# 1         Stadtbezirk 02 Ludwigsvorstadt-Isarvorstadt  48.130722  11.566526
# 2                          Stadtbezirk 03 Maxvorstadt  48.146570  11.571445
# 3                       Stadtbezirk 04 Schwabing-West  48.166354  11.566191
# 4                        Stadtbezirk 05 Au-Haidhausen  48.130274  11.598334
# 5                             Stadtbezirk 06 Sendling  48.115921  11.548387
# 6                    Stadtbezirk 07 Sendling-Westpark  48.118031  11.519333
# 7                     Stadtbezirk 08 Schwanthalerhöhe  48.134589  11.538013
# 8                Stadtbezirk 09 Neuhausen-Nymphenburg  48.156626  11.518016
# 9                              Stadtbezirk 10 Moosach  48.185426  11.515594
# 10               Stadtbezirk 11 Milbertshofen-Am Hart  48.197532  11.577300
# 11                  Stadtbezirk 12 Schwabing-Freimann  48.189278  11.608583
# 12                         Stadtbezirk 13 Bogenhausen  48.158487  11.636682
# 13                        Stadtbezirk 14 Berg am Laim  48.125613  11.629557
# 14                      Stadtbezirk 15 Trudering-Riem  48.126678  11.685296
# 15                  Stadtbezirk 16 Ramersdorf-Perlach  48.100894  11.633371
# 16             Stadtbezirk 17 Obergiesing-Fasangarten  48.103934  11.590683
# 17             Stadtbezirk 18 Untergiesing-Harlaching  48.095380  11.569129
# 18  Stadtbezirk 19 Thalkirchen-Obersendling-Forste...  48.084213  11.508051
# 19                              Stadtbezirk 20 Hadern  48.113193  11.482850
# 20                  Stadtbezirk 21 Pasing-Obermenzing  48.152363  11.468434
# 21          Stadtbezirk 22 Aubing-Lochhausen-Langwied  48.165059  11.400221
# 22                 Stadtbezirk 23 Allach-Untermenzing  48.195157  11.462973
# 23              Stadtbezirk 24 Feldmoching-Hasenbergl  48.218462  11.520409
# 24                                Stadtbezirk 25 Laim  48.136310  11.505333

# %% [markdown]
# ### Conclusions
# The initial data frame was created with the distrcit names and corresponding coordinates. In the following we will concentrate on the major business districts:
# * Altstadt-Lehel
# * Schwabing-West
# * Au-Haidhausen
# * Ludwigsvorstadt-Isarvorstadt
# * Maxvorstadt
#
# ### Pitfalls
# * The search term for the geocoder needs to have a specific format. Initially, just using the district name in the query, coordinates of some place within the district were returned. The latter was revealed by plotting the district coordinates in a map and manual cross-check on https://nominatim.openstreetmap.org/search.php
# * The geocoder query may lead to timeout errors if the full list is passed. These errors could be circumvented by manually looping through the dataframe row by row.
